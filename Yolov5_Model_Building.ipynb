# %% [markdown]
# # **Computer Vision Hackathon 2024 - MCA 571**

# %% [markdown]
# **Yolov5 Model training And testing Code**

# %% [markdown]
# **1. Setting up the Environment**

# %%
import torch

# %%
from IPython.display import Image

# %%
# %cd yolov5
# Out:
# c:\Users\Kalpana\Documents\CV\Hackathon\yolov5

# %% [markdown]
# * import torch: Imports PyTorch, the deep learning framework used to train YOLOv5.
# * from IPython.display import Image: Imports a function to display images in a Jupyter notebook environment.
# * %cd yolov5: Changes the directory to yolov5, which contains the YOLOv5 code.

# %% [markdown]
# **2. Installing Dependencies**

# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gitpython>=3.1.30 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 5)) (3.1.42)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 6)) (3.7.2)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 8)) (4.9.0.80)
# Requirement already satisfied: pillow>=10.3.0 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 9)) (11.0.0)
# Requirement already satisfied: psutil in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: requests>=2.32.2 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 13)) (1.12.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 15)) (2.5.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 16)) (0.20.1+cpu)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 17)) (4.66.6)
# Requirement already satisfied: ultralytics>=8.2.34 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 18)) (8.3.27)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 27)) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 28)) (0.12.2)
# Requirement already satisfied: setuptools>=70.0.0 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 42)) (75.3.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2024.7.4)
# Requirement already satisfied: filelock in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.9.0)
# Requirement already satisfied: networkx in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from sympy==1.13.1->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: colorama in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from tqdm>=4.66.3->-r requirements.txt (line 17)) (0.4.6)
# Requirement already satisfied: py-cpuinfo in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (2.0.10)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kalpana\appdata\roaming\python\python311\site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.3)
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# * Installs the required dependencies listed in requirements.txt. This file includes libraries such as torch, opencv-python, matplotlib, and more, which are necessary for training the YOLOv5 model.

# %% [markdown]
# **3. Setting Up YOLOv5 Configuration**

# %%
{
  "version": "0.0.6",
  "runs_dir": "C:/Users/Kalpana/Documents/CV/Hackathon/yolov5/runs"
}
# Out:
# {'version': '0.0.6',
#  'runs_dir': 'C:/Users/Kalpana/Documents/CV/Hackathon/yolov5/runs'}

# %% [markdown]
# * This configuration sets the YOLOv5 version and the directory (runs_dir) where training results and logs will be saved.

# %% [markdown]
# **4. Setting Environment Variables**

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

# %% [markdown]
# * This sets an environment variable (KMP_DUPLICATE_LIB_OK=TRUE) to avoid issues with multiple threads in certain libraries. This is often needed when using libraries like PyTorch and OpenCV together.

# %% [markdown]
# **5. Training the YOLOv5 Model**

# %%
# !set KMP_DUPLICATE_LIB_OK=TRUE
# !python train.py --img 640 --batch 8 --epochs 5 --data C:/Users/Kalpana/Documents/CV/Hackathon/yolov5/data.yaml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=C:/Users/Kalpana/Documents/CV/Hackathon/yolov5/data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=5, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# From https://github.com/ultralytics/yolov5
#    81ac034a..882c35fc  master     -> origin/master
# github:  YOLOv5 is out of date by 5 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5  v7.0-383-g1435a8ee Python-3.11.4 torch-2.5.1+cpu CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5  runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/Arial.ttf to C:\Users\Kalpana\AppData\Roaming\Ultralytics\Arial.ttf...
#
#   0%|          | 0.00/755k [00:00<?, ?B/s]
#  17%|█▋        | 128k/755k [00:00<00:01, 580kB/s]
#  34%|███▍      | 256k/755k [00:00<00:01, 264kB/s]
#  51%|█████     | 384k/755k [00:01<00:02, 184kB/s]
#  68%|██████▊   | 512k/755k [00:03<00:01, 140kB/s]
#  85%|████████▍ | 640k/755k [00:04<00:00, 123kB/s]
# 100%|██████████| 755k/755k [00:05<00:00, 129kB/s]
# 100%|██████████| 755k/755k [00:05<00:00, 146kB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
#
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels...:   0%|          | 0/2508 [00:00<?, ?it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1 images, 0 backgrounds, 0 corrupt:   0%|          | 1/2508 [00:24<16:57:00, 24.34s/it]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 44 images, 0 backgrounds, 0 corrupt:   2%|▏         | 44/2508 [00:24<16:06,  2.55it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 86 images, 0 backgrounds, 0 corrupt:   3%|▎         | 86/2508 [00:24<06:44,  5.99it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 126 images, 0 backgrounds, 0 corrupt:   5%|▌         | 126/2508 [00:24<03:45, 10.58it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 165 images, 0 backgrounds, 0 corrupt:   7%|▋         | 165/2508 [00:24<02:20, 16.71it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 201 images, 0 backgrounds, 0 corrupt:   8%|▊         | 201/2508 [00:24<01:34, 24.36it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 234 images, 0 backgrounds, 0 corrupt:   9%|▉         | 234/2508 [00:25<01:07, 33.86it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 267 images, 0 backgrounds, 0 corrupt:  11%|█         | 267/2508 [00:25<00:48, 45.91it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 298 images, 0 backgrounds, 0 corrupt:  12%|█▏        | 298/2508 [00:25<00:36, 60.41it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 328 images, 0 backgrounds, 0 corrupt:  13%|█▎        | 328/2508 [00:25<00:27, 78.12it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 358 images, 0 backgrounds, 0 corrupt:  14%|█▍        | 358/2508 [00:25<00:22, 96.17it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 388 images, 0 backgrounds, 0 corrupt:  15%|█▌        | 388/2508 [00:25<00:18, 112.72it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 430 images, 0 backgrounds, 0 corrupt:  17%|█▋        | 430/2508 [00:25<00:13, 153.77it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 468 images, 0 backgrounds, 0 corrupt:  19%|█▊        | 468/2508 [00:25<00:10, 188.56it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 511 images, 0 backgrounds, 0 corrupt:  20%|██        | 511/2508 [00:25<00:08, 230.55it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 548 images, 0 backgrounds, 0 corrupt:  22%|██▏       | 548/2508 [00:26<00:07, 247.03it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 585 images, 0 backgrounds, 0 corrupt:  23%|██▎       | 585/2508 [00:26<00:07, 269.11it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 626 images, 0 backgrounds, 0 corrupt:  25%|██▍       | 626/2508 [00:26<00:06, 301.36it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 670 images, 0 backgrounds, 0 corrupt:  27%|██▋       | 670/2508 [00:26<00:05, 331.16it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 709 images, 0 backgrounds, 0 corrupt:  28%|██▊       | 709/2508 [00:26<00:05, 345.50it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 747 images, 0 backgrounds, 0 corrupt:  30%|██▉       | 747/2508 [00:26<00:04, 354.23it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 785 images, 0 backgrounds, 0 corrupt:  31%|███▏      | 785/2508 [00:26<00:04, 359.38it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 823 images, 0 backgrounds, 0 corrupt:  33%|███▎      | 823/2508 [00:26<00:05, 312.68it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 859 images, 0 backgrounds, 0 corrupt:  34%|███▍      | 859/2508 [00:26<00:05, 323.38it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 901 images, 0 backgrounds, 0 corrupt:  36%|███▌      | 901/2508 [00:27<00:04, 343.45it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 937 images, 0 backgrounds, 0 corrupt:  37%|███▋      | 937/2508 [00:27<00:04, 330.15it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 971 images, 0 backgrounds, 0 corrupt:  39%|███▊      | 971/2508 [00:27<00:04, 326.26it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1007 images, 0 backgrounds, 0 corrupt:  40%|████      | 1007/2508 [00:27<00:04, 329.71it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1041 images, 0 backgrounds, 0 corrupt:  42%|████▏     | 1041/2508 [00:27<00:04, 328.87it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1079 images, 0 backgrounds, 0 corrupt:  43%|████▎     | 1079/2508 [00:27<00:04, 332.00it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1114 images, 0 backgrounds, 0 corrupt:  44%|████▍     | 1114/2508 [00:27<00:04, 333.88it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1152 images, 0 backgrounds, 0 corrupt:  46%|████▌     | 1152/2508 [00:27<00:03, 344.62it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1190 images, 0 backgrounds, 0 corrupt:  47%|████▋     | 1190/2508 [00:27<00:03, 350.63it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1229 images, 0 backgrounds, 0 corrupt:  49%|████▉     | 1229/2508 [00:28<00:03, 361.62it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1266 images, 0 backgrounds, 0 corrupt:  50%|█████     | 1266/2508 [00:28<00:03, 321.51it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1300 images, 0 backgrounds, 0 corrupt:  52%|█████▏    | 1300/2508 [00:28<00:03, 303.25it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1333 images, 0 backgrounds, 0 corrupt:  53%|█████▎    | 1333/2508 [00:28<00:03, 301.81it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1364 images, 0 backgrounds, 0 corrupt:  54%|█████▍    | 1364/2508 [00:28<00:03, 298.37it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1395 images, 0 backgrounds, 0 corrupt:  56%|█████▌    | 1395/2508 [00:28<00:03, 296.60it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1429 images, 0 backgrounds, 0 corrupt:  57%|█████▋    | 1429/2508 [00:28<00:03, 294.15it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1459 images, 0 backgrounds, 0 corrupt:  58%|█████▊    | 1459/2508 [00:28<00:03, 289.02it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1493 images, 0 backgrounds, 0 corrupt:  60%|█████▉    | 1493/2508 [00:28<00:03, 295.46it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1523 images, 0 backgrounds, 0 corrupt:  61%|██████    | 1523/2508 [00:29<00:03, 274.80it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1559 images, 0 backgrounds, 0 corrupt:  62%|██████▏   | 1559/2508 [00:29<00:03, 286.17it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1590 images, 0 backgrounds, 0 corrupt:  63%|██████▎   | 1590/2508 [00:29<00:03, 280.52it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1619 images, 0 backgrounds, 0 corrupt:  65%|██████▍   | 1619/2508 [00:29<00:03, 273.68it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1647 images, 0 backgrounds, 0 corrupt:  66%|██████▌   | 1647/2508 [00:29<00:03, 258.51it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1676 images, 0 backgrounds, 0 corrupt:  67%|██████▋   | 1676/2508 [00:29<00:03, 262.30it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1703 images, 0 backgrounds, 0 corrupt:  68%|██████▊   | 1703/2508 [00:29<00:03, 257.39it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1729 images, 0 backgrounds, 0 corrupt:  69%|██████▉   | 1729/2508 [00:29<00:03, 257.73it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1756 images, 0 backgrounds, 0 corrupt:  70%|███████   | 1756/2508 [00:30<00:02, 255.76it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1783 images, 0 backgrounds, 0 corrupt:  71%|███████   | 1783/2508 [00:30<00:02, 257.97it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1809 images, 0 backgrounds, 0 corrupt:  72%|███████▏  | 1809/2508 [00:30<00:03, 225.73it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1834 images, 0 backgrounds, 0 corrupt:  73%|███████▎  | 1834/2508 [00:30<00:02, 227.59it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1866 images, 0 backgrounds, 0 corrupt:  74%|███████▍  | 1866/2508 [00:30<00:02, 249.72it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1904 images, 0 backgrounds, 0 corrupt:  76%|███████▌  | 1904/2508 [00:30<00:02, 281.64it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1936 images, 0 backgrounds, 0 corrupt:  77%|███████▋  | 1936/2508 [00:30<00:02, 271.59it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 1972 images, 0 backgrounds, 0 corrupt:  79%|███████▊  | 1972/2508 [00:30<00:01, 292.73it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2006 images, 0 backgrounds, 0 corrupt:  80%|███████▉  | 2006/2508 [00:30<00:01, 298.87it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2044 images, 0 backgrounds, 0 corrupt:  81%|████████▏ | 2044/2508 [00:31<00:01, 320.11it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2077 images, 0 backgrounds, 0 corrupt:  83%|████████▎ | 2077/2508 [00:31<00:01, 321.61it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2110 images, 0 backgrounds, 0 corrupt:  84%|████████▍ | 2110/2508 [00:31<00:01, 314.86it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2148 images, 0 backgrounds, 0 corrupt:  86%|████████▌ | 2148/2508 [00:31<00:01, 332.05it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2185 images, 0 backgrounds, 0 corrupt:  87%|████████▋ | 2185/2508 [00:31<00:00, 339.34it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2220 images, 0 backgrounds, 0 corrupt:  89%|████████▊ | 2220/2508 [00:31<00:00, 329.85it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2254 images, 0 backgrounds, 0 corrupt:  90%|████████▉ | 2254/2508 [00:31<00:00, 328.21it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2287 images, 0 backgrounds, 0 corrupt:  91%|█████████ | 2287/2508 [00:31<00:00, 296.19it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2318 images, 0 backgrounds, 0 corrupt:  92%|█████████▏| 2318/2508 [00:31<00:00, 299.68it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2353 images, 0 backgrounds, 0 corrupt:  94%|█████████▍| 2353/2508 [00:31<00:00, 312.32it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2385 images, 0 backgrounds, 0 corrupt:  95%|█████████▌| 2385/2508 [00:32<00:00, 313.60it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2417 images, 0 backgrounds, 0 corrupt:  96%|█████████▋| 2417/2508 [00:32<00:00, 310.50it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2450 images, 0 backgrounds, 0 corrupt:  98%|█████████▊| 2450/2508 [00:32<00:00, 309.78it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2485 images, 0 backgrounds, 0 corrupt:  99%|█████████▉| 2485/2508 [00:32<00:00, 308.06it/s]
# train: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels... 2508 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2508/2508 [00:32<00:00, 77.03it/s]
# train: New cache created: C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\train\labels.cache
#
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels...:   0%|          | 0/1008 [00:00<?, ?it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 1 images, 0 backgrounds, 0 corrupt:   0%|          | 1/1008 [00:25<7:02:15, 25.16s/it]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 4 images, 0 backgrounds, 0 corrupt:   0%|          | 4/1008 [00:25<1:20:06,  4.79s/it]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 11 images, 0 backgrounds, 0 corrupt:   1%|          | 11/1008 [00:25<21:39,  1.30s/it]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 20 images, 0 backgrounds, 0 corrupt:   2%|▏         | 20/1008 [00:25<09:16,  1.77it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 31 images, 0 backgrounds, 0 corrupt:   3%|▎         | 31/1008 [00:25<04:40,  3.49it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 42 images, 0 backgrounds, 0 corrupt:   4%|▍         | 42/1008 [00:25<02:45,  5.84it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 55 images, 0 backgrounds, 0 corrupt:   5%|▌         | 55/1008 [00:25<01:39,  9.59it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 69 images, 0 backgrounds, 0 corrupt:   7%|▋         | 69/1008 [00:25<01:02, 14.98it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 82 images, 0 backgrounds, 0 corrupt:   8%|▊         | 82/1008 [00:26<00:43, 21.42it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 99 images, 0 backgrounds, 0 corrupt:  10%|▉         | 99/1008 [00:26<00:28, 32.39it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 129 images, 0 backgrounds, 0 corrupt:  13%|█▎        | 129/1008 [00:26<00:15, 57.48it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 155 images, 0 backgrounds, 0 corrupt:  15%|█▌        | 155/1008 [00:26<00:10, 81.22it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 177 images, 0 backgrounds, 0 corrupt:  18%|█▊        | 177/1008 [00:26<00:08, 100.24it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 197 images, 0 backgrounds, 0 corrupt:  20%|█▉        | 197/1008 [00:26<00:07, 114.75it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 217 images, 0 backgrounds, 0 corrupt:  22%|██▏       | 217/1008 [00:26<00:06, 130.77it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 243 images, 0 backgrounds, 0 corrupt:  24%|██▍       | 243/1008 [00:26<00:04, 155.83it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 264 images, 0 backgrounds, 0 corrupt:  26%|██▌       | 264/1008 [00:26<00:04, 164.79it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 290 images, 0 backgrounds, 0 corrupt:  29%|██▉       | 290/1008 [00:26<00:03, 182.20it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 319 images, 0 backgrounds, 0 corrupt:  32%|███▏      | 319/1008 [00:27<00:03, 203.54it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 346 images, 0 backgrounds, 0 corrupt:  34%|███▍      | 346/1008 [00:27<00:03, 201.71it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 390 images, 0 backgrounds, 0 corrupt:  39%|███▊      | 390/1008 [00:27<00:02, 259.46it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 425 images, 0 backgrounds, 0 corrupt:  42%|████▏     | 425/1008 [00:27<00:02, 281.97it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 458 images, 0 backgrounds, 0 corrupt:  45%|████▌     | 458/1008 [00:27<00:01, 293.67it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 492 images, 0 backgrounds, 0 corrupt:  49%|████▉     | 492/1008 [00:27<00:01, 302.26it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 524 images, 0 backgrounds, 0 corrupt:  52%|█████▏    | 524/1008 [00:27<00:01, 301.70it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 555 images, 0 backgrounds, 0 corrupt:  55%|█████▌    | 555/1008 [00:27<00:01, 289.16it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 589 images, 0 backgrounds, 0 corrupt:  58%|█████▊    | 589/1008 [00:27<00:01, 300.70it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 629 images, 0 backgrounds, 0 corrupt:  62%|██████▏   | 629/1008 [00:28<00:01, 328.37it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 663 images, 0 backgrounds, 0 corrupt:  66%|██████▌   | 663/1008 [00:28<00:01, 330.20it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 697 images, 0 backgrounds, 0 corrupt:  69%|██████▉   | 697/1008 [00:28<00:00, 313.09it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 733 images, 0 backgrounds, 0 corrupt:  73%|███████▎  | 733/1008 [00:28<00:00, 313.09it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 765 images, 0 backgrounds, 0 corrupt:  76%|███████▌  | 765/1008 [00:28<00:00, 281.80it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 795 images, 0 backgrounds, 0 corrupt:  79%|███████▉  | 795/1008 [00:28<00:00, 276.60it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 824 images, 0 backgrounds, 0 corrupt:  82%|████████▏ | 824/1008 [00:28<00:00, 260.79it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 864 images, 0 backgrounds, 0 corrupt:  86%|████████▌ | 864/1008 [00:28<00:00, 291.13it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 900 images, 0 backgrounds, 0 corrupt:  89%|████████▉ | 900/1008 [00:29<00:00, 300.96it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 938 images, 0 backgrounds, 0 corrupt:  93%|█████████▎| 938/1008 [00:29<00:00, 320.11it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 985 images, 0 backgrounds, 0 corrupt:  98%|█████████▊| 985/1008 [00:29<00:00, 356.61it/s]
# val: Scanning C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels... 1008 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1008/1008 [00:29<00:00, 34.43it/s]
# val: New cache created: C:\Users\Kalpana\Documents\CV\Hackathon\dataset1\dataset1\valid\labels.cache
#
# AutoAnchor: 3.99 anchors/target, 0.982 Best Possible Recall (BPR). Current anchors are a good fit to dataset
# Plotting labels to runs\train\exp2\labels.jpg...
# c:\Users\Kalpana\Documents\CV\Hackathon\yolov5\train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs\train\exp2
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/314 [00:00<?, ?it/s]c:\Users\Kalpana\Documents\CV\Hackathon\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#         0/4         0G     0.1192    0.03476          0         21        640:   0%|          | 0/314 [00:16<?, ?it/s]
#         0/4         0G     0.1192    0.03476          0         21        640:   0%|          | 1/314 [00:20<1:46:02, 20.33s/it]c:\Users\Kalpana\Documents\CV\Hackathon\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#         0/4         0G      0.126    0.03303          0         16        640:   0%|          | 1/314 [00:27<1:46:02, 20.33s/it]
#         0/4         0G      0.126    0.03303          0         16        640:   1%|          | 2/314 [00:27<1:06:15, 12.74s/it]c:\Users\Kalpana\Documents\CV\Hackathon\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#         0/4         0G      0.124    0.03398          0         28        640:   1%|          | 2/314 [00:34<1:06:15, 12.74s/it]
#         0/4         0G      0.124    0.03398          0         28        640:   1%|          | 3/314 [00:34<52:39, 10.16s/it]  c:\Users\Kalpana\Documents\CV\Hackathon\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#         0/4         0G      0.123    0.03451          0         27        640:   1%|          | 3/314 [00:41<52:39, 10.16s/it]
#         0/4         0G      0.123    0.03451          0         27        640:   1%|▏         | 4/314 [00:41<46:02,  8.91s/it]c:\Users\Kalpana\Documents\CV\Hackathon\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#         0/4         0G     0.1234    0.03412          0         24        640:   1%|▏         | 4/314 [00:48<46:02,  8.91s/it]
#         0/4         0G     0.1234    0.03412          0         24        640:   2%|▏         | 5/314 [00:48<42:19,  8.22s/it]c:\Users\Kalpana\Documents\CV\Hackathon\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#         0/4         0G     0.1233    0.03365          0         19        640:   2%|▏         | 5/314 [00:55<42:19,  8.22s/it]
#         0/4         0G     0.1233    0.03365          0         19        640:   2%|▏         | 6/314 [00:55<40:20,  7.86s/it]c:\Users\Kalpana\Documents\CV\Hackathon\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#         0/4         0G     0.1235    0.03338          0         21        640:   2%|▏         | 6/314 [01:03<40:20,  7.86s/it]
#         0/4         0G     0.1235    0.03338          0         21        640:   2%|▏         | 7/314 [01:03<39:06,  7.64s/it]c:\Users\Kalpana\Documents\CV\Hackathon\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#         0/4         0G      0.123    0.03323          0         20        640:   2%|▏         | 7/314 [01:10<39:06,  7.64s/it]
#         0/4         0G      0.123    0.03323          0         20        640:   3%|▎         | 8/314 [01:10<37:57,  7.44s/it]c:\Users\Kalpana\Documents\CV\Hackathon\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#         0/4         0G     0.1228    0.03269          0         14        640:   3%|▎         | 8/314 [01:18<37:57,  7.44s/it]
#         0/4         0G     0.1228    0.03269          0         14        640:   3%|▎         | 9/314 [01:18<39:03,  7.68s/it]c:\Users\Kalpana\Documents\CV\Hackathon\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#         0/4         0G     0.
  3.17s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  14%|█▍        | 9/63 [00:28<02:51,  3.17s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  16%|█▌        | 10/63 [00:32<02:48,  3.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  17%|█▋        | 11/63 [00:35<02:43,  3.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  19%|█▉        | 12/63 [00:38<02:41,  3.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  21%|██        | 13/63 [00:41<02:37,  3.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  22%|██▏       | 14/63 [00:44<02:34,  3.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  24%|██▍       | 15/63 [00:47<02:30,  3.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  25%|██▌       | 16/63 [00:50<02:27,  3.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  27%|██▋       | 17/63 [00:54<02:24,  3.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  29%|██▊       | 18/63 [00:57<02:21,  3.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  30%|███       | 19/63 [01:00<02:19,  3.17s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  32%|███▏      | 20/63 [01:03<02:16,  3.17s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  33%|███▎      | 21/63 [01:06<02:12,  3.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  35%|███▍      | 22/63 [01:09<02:09,  3.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  37%|███▋      | 23/63 [01:13<02:05,  3.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  38%|███▊      | 24/63 [01:16<02:02,  3.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  40%|███▉      | 25/63 [01:19<02:00,  3.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  41%|████▏     | 26/63 [01:22<01:56,  3.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  43%|████▎     | 27/63 [01:25<01:52,  3.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  44%|████▍     | 28/63 [01:28<01:49,  3.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  46%|████▌     | 29/63 [01:31<01:46,  3.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  48%|████▊     | 30/63 [01:35<01:43,  3.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  49%|████▉     | 31/63 [01:38<01:40,  3.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  51%|█████     | 32/63 [01:41<01:37,  3.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  52%|█████▏    | 33/63 [01:44<01:34,  3.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  54%|█████▍    | 34/63 [01:47<01:30,  3.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  56%|█████▌    | 35/63 [01:50<01:27,  3.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  57%|█████▋    | 36/63 [01:53<01:24,  3.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  59%|█████▊    | 37/63 [01:56<01:21,  3.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  60%|██████    | 38/63 [02:00<01:18,  3.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  62%|██████▏   | 39/63 [02:03<01:14,  3.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  63%|██████▎   | 40/63 [02:06<01:11,  3.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  65%|██████▌   | 41/63 [02:09<01:09,  3.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  67%|██████▋   | 42/63 [02:12<01:05,  3.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  68%|██████▊   | 43/63 [02:15<01:02,  3.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  70%|██████▉   | 44/63 [02:18<00:59,  3.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  71%|███████▏  | 45/63 [02:21<00:56,  3.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  73%|███████▎  | 46/63 [02:25<00:53,  3.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  75%|███████▍  | 47/63 [02:28<00:50,  3.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  76%|███████▌  | 48/63 [02:31<00:47,  3.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  78%|███████▊  | 49/63 [02:34<00:43,  3.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  79%|███████▉  | 50/63 [02:37<00:40,  3.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  81%|████████  | 51/63 [02:40<00:37,  3.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  83%|████████▎ | 52/63 [02:43<00:34,  3.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  84%|████████▍ | 53/63 [02:47<00:31,  3.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  86%|████████▌ | 54/63 [02:50<00:28,  3.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  87%|████████▋ | 55/63 [02:53<00:25,  3.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  89%|████████▉ | 56/63 [02:56<00:22,  3.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  90%|█████████ | 57/63 [02:59<00:18,  3.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  92%|█████████▏| 58/63 [03:02<00:15,  3.19s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  94%|█████████▎| 59/63 [03:06<00:12,  3.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  95%|█████████▌| 60/63 [03:09<00:09,  3.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  97%|█████████▋| 61/63 [03:12<00:06,  3.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  98%|█████████▊| 62/63 [03:15<00:03,  3.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 63/63 [03:18<00:00,  3.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 63/63 [03:18<00:00,  3.15s/it]
#                    all       1008       1468      0.809      0.733      0.738      0.494
# Results saved to runs\train\exp2

# %% [markdown]
# -> This command starts the training of the YOLOv5 model. Let’s break it down:
#
# * python train.py: This runs the train.py script, which is responsible for training the YOLOv5 model.
#
# * --img 640: Specifies that the input image size for training should be 640x640 pixels.
# * --batch 8: Sets the batch size (number of images processed together) to 8.
# * --epochs 5: The model will train for 5 epochs (iterations over the entire dataset).
# * --data C:/Users/Kalpana/Documents/CV/Hackathon/yolov5/data.yaml: Specifies the location of the data.yaml file, which contains the paths to your training and validation datasets.
# * --weights yolov5s.pt: Specifies the pre-trained weights (yolov5s.pt) to use as the starting point for training. The yolov5s.pt model is a smaller, more
# * efficient variant of YOLOv5.
# --workers 2: Uses 2 CPU workers to load the data during training.

# %% [markdown]
# The model is training here and it takes 1 hour to train as we have 8000 data files.

# %% [markdown]
# **6. Dependency Installation Output**

# %%
# !python detect.py --source C:/Users/Kalpana/Documents/CV/Hackathon/yolov5/runs/train/exp2/0ccd6b18-705e-48f3-b0df-0cb4797bc515_jpg.rf.fb630507a2a437a0e17b5149fbf7637d.jpg --weights C:/Users/Kalpana/Documents/CV/Hackathon/yolov5/runs/train/exp2/weights/best.pt
# Out:
# detect: weights=['C:/Users/Kalpana/Documents/CV/Hackathon/yolov5/runs/train/exp2/weights/best.pt'], source=C:/Users/Kalpana/Documents/CV/Hackathon/yolov5/runs/train/exp2/0ccd6b18-705e-48f3-b0df-0cb4797bc515_jpg.rf.fb630507a2a437a0e17b5149fbf7637d.jpg, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-383-g1435a8ee Python-3.11.4 torch-2.5.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 C:\Users\Kalpana\Documents\CV\Hackathon\yolov5\runs\train\exp2\0ccd6b18-705e-48f3-b0df-0cb4797bc515_jpg.rf.fb630507a2a437a0e17b5149fbf7637d.jpg: 640x640 1 LicensePlate, 170.2ms
# Speed: 5.4ms pre-process, 170.2ms inference, 8.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\exp4

# %% [markdown]
# * The output shows that all required dependencies have been successfully installed (like gitpython, opencv-python, torch, etc.). These dependencies are crucial for the YOLOv5 model to function properly.

# %% [markdown]
# **7. Warning about YOLOv5 Version**

# %% [markdown]
# * The output indicates that the YOLOv5 repository is out of date by 5 commits. This message is informational, reminding you that a newer version of the YOLOv5 code is available.

# %% [markdown]
# **8. Training Configuration**
# * The training hyperparameters are set as per the default configurations in YOLOv5, such as learning rate (lr0), momentum, weight decay, etc.
# The hyp.scratch-low.yaml file is used for the hyperparameters, which defines values like box loss weight, objectness loss, and class loss.
#
# **9. Downloading Resources**
# * The model begins downloading required files like the Arial font for visualizing results.

# %%
# !python detect.py --source C:/Users/Kalpana/Documents/CV/Hackathon/yolov5/runs/train/exp2/0dc72cde-2c7c-4ac8-8b04-187914f68f2b_jpg.rf.108506c58f87e775cb11acd094290bbe.jpg --weights C:/Users/Kalpana/Documents/CV/Hackathon/yolov5/runs/train/exp2/weights/best.pt
# Out:
# detect: weights=['C:/Users/Kalpana/Documents/CV/Hackathon/yolov5/runs/train/exp2/weights/best.pt'], source=C:/Users/Kalpana/Documents/CV/Hackathon/yolov5/runs/train/exp2/0dc72cde-2c7c-4ac8-8b04-187914f68f2b_jpg.rf.108506c58f87e775cb11acd094290bbe.jpg, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-383-g1435a8ee Python-3.11.4 torch-2.5.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 C:\Users\Kalpana\Documents\CV\Hackathon\yolov5\runs\train\exp2\0dc72cde-2c7c-4ac8-8b04-187914f68f2b_jpg.rf.108506c58f87e775cb11acd094290bbe.jpg: 640x640 1 LicensePlate, 174.2ms
# Speed: 0.0ms pre-process, 174.2ms inference, 2.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\exp5

# %% [markdown]
# **10. Model Training Process**
# * The model starts the training process, where the dataset specified in data.yaml is used to train the YOLOv5 model. The yolov5s.pt weights are loaded, and the training process will optimize the model over the course of 5 epochs.
# Key Points to Track During Training:
# Training Metrics: Monitor metrics like loss, mAP (mean Average Precision), and accuracy during training to understand the model’s performance.
# Saved Weights: After training, the best model weights will be saved in the runs_dir directory, and you can use those weights for inference or further fine-tuning.
#
# **11. Visualizing and Monitoring Training Progress**
# * Once training starts, you can track the progress by:
# TensorBoard: By running tensorboard --logdir runs/train, you can monitor training graphs such as loss curves and mAP score.
# Comet.ml (optional): You can use comet_ml for more advanced tracking of training runs.

# %% [markdown]
# **The YOLOv5 model training involves setting up the environment, preparing the dataset, and configuring model settings such as architecture and hyperparameters. The model is then trained, monitored for performance, and the best-performing model is saved for future use, followed by testing the model for object detection accuracy.**
